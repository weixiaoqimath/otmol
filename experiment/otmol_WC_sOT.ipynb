# %%
# %%
import otmol as otm
import pandas as pd
from openbabel import pybel
import matplotlib.pyplot as plt
import os
from experiment_utils import wc_experiment
# %matplotlib widget

# %%
method = 'sOT'

# %%
data_path = "../Data/Water-Clusters"
mol_pair_list_path = os.path.join(data_path, 'list')
_molecule_pairs = otm.tl.parse_molecule_pairs(mol_pair_list_path, mol_type='water cluster')
molecule_pairs = []
for nameA, nameB in _molecule_pairs:
    molecule_pairs.append((nameA+'.xyz', nameB+'.xyz'))
otmol_res = wc_experiment(molecule_pairs, data_path, method = method, dataset_name = 'ArbAlignDataWC')
# Out:
# The number of candidate molecular level permutations is 2
# 2-Cs-1.xyz 2-OpenC1.xyz sOT 0.32 0.01s
# The number of candidate molecular level permutations is 6
# 3-UUD.xyz 3-UUU.xyz sOT 0.31 0.43s
# The number of candidate molecular level permutations is 5
# 4-Ci.xyz 4-S4.xyz sOT 0.49 0.41s
# The number of candidate molecular level permutations is 35
# 5-CA-A.xyz 5-CA-B.xyz sOT 0.76 0.44s
# The number of candidate molecular level permutations is 33
# 6-BAG.xyz 6-BK-1.xyz sOT 1.04 0.45s
# The number of candidate molecular level permutations is 39
# 7-BI1.xyz 7-BI2.xyz sOT 0.45 0.46s
# The number of candidate molecular level permutations is 60
# 8-D2d.xyz 8-S4.xyz sOT 0.61 0.48s
# The number of candidate molecular level permutations is 78
# 9-D2dDD.xyz 9-S4DA.xyz sOT 0.64 0.50s
# The number of candidate molecular level permutations is 310
# 10-PP1.xyz 10-PP2.xyz sOT 0.64 0.76s
# The number of candidate molecular level permutations is 152
# 11-551A-1.xyz 11-551A-4.xyz sOT 0.14 0.60s
# The number of candidate molecular level permutations is 314
# 12-D2d-1-L.xyz 12-D2d-1-R.xyz sOT 0.51 0.81s
# The number of candidate molecular level permutations is 237
# 13-TIP4P.xyz 13-TIP5P.xyz sOT 1.23 0.74s
# The number of candidate molecular level permutations is 284
# 14-1.xyz 14-2.xyz sOT 0.55 0.83s
# The number of candidate molecular level permutations is 375
# 15-1.xyz 15-2.xyz sOT 1.23 1.09s
# The number of candidate molecular level permutations is 399
# 16-TIP4P.xyz 16-TIP5P.xyz sOT 1.61 1.04s
# The number of candidate molecular level permutations is 337
# 17-TIP4P.xyz 17-TIP5P.xyz sOT 1.22 1.00s
# The number of candidate molecular level permutations is 373
# 18-TIP4P.xyz 18-TIP5P.xyz sOT 1.50 1.10s
# The number of candidate molecular level permutations is 455
# 19-TIP4P.xyz 19-TIP5P.xyz sOT 1.42 1.21s
# The number of candidate molecular level permutations is 468
# 20-TIP4P.xyz 20-TIP5P.xyz sOT 1.82 1.32s
# The number of candidate molecular level permutations is 489
# 21-TIP4P.xyz 21-TIP5P.xyz sOT 1.39 1.37s
# The number of candidate molecular level permutations is 347
# 25-1.xyz 25-2.xyz sOT 0.96 1.37s
# The number of candidate molecular level permutations is 496
# 40-a.xyz 40-b.xyz sOT 2.28 2.75s
# The number of candidate molecular level permutations is 496
# 60-1.xyz 60-2.xyz sOT 2.06 4.59s
# The number of candidate molecular level permutations is 500
# 100-1.xyz 100-2.xyz sOT 2.08 11.12s

# %%
arbalign_res = pd.read_csv(os.path.join(data_path, 'rmsd-2017.dat'), sep='\s+')
combined_df = pd.concat([otmol_res, arbalign_res], axis=1).rename(columns={'RMSD(KM-ByAtomName)': 'RMSD(ArbAlign)'})
columns_to_plot = ["RMSD(ArbAlign)", "RMSD(OTMol)"]
plt.figure(figsize=(10, 6))
for column in columns_to_plot:
    plt.plot(range(len(combined_df['#'])), combined_df[column], marker='o', label=column)
plt.xticks(range(len(combined_df['#'])), combined_df['#'])
plt.title("Water Cluster Dataset from ArbAlign paper")
plt.ylabel("RMSD Values")
plt.legend()
plt.grid(True)

# %%
group1_data_path = "../Data/Our_Benchmark_20250410_ver1/Water_Cluster_3_30/water_xyz_output_1st_2nd"
group1_info = pd.read_csv('../Data/Our_Benchmark_20250410_ver1/Water_Cluster_3_30/water_cluster_1st_2nd_lowest_energy.csv')
group1_res = wc_experiment(zip(group1_info['Reference'], group1_info['Target']), group1_data_path, method = method, dataset_name = '1st2nd')
# Out:
# The number of candidate molecular level permutations is 6
# Wat_3_cluster_0_1st_lowest.xyz Wat_3_cluster_1_2nd_lowest.xyz sOT 1.49 0.43s
# The number of candidate molecular level permutations is 24
# Wat_4_cluster_2_1st_lowest.xyz Wat_4_cluster_3_2nd_lowest.xyz sOT 0.95 0.44s
# The number of candidate molecular level permutations is 47
# Wat_5_cluster_12_1st_lowest.xyz Wat_5_cluster_13_2nd_lowest.xyz sOT 0.13 0.47s
# The number of candidate molecular level permutations is 10
# Wat_6_cluster_31_1st_lowest.xyz Wat_6_cluster_32_2nd_lowest.xyz sOT 0.22 0.43s
# The number of candidate molecular level permutations is 55
# Wat_7_cluster_137_1st_lowest.xyz Wat_7_cluster_138_2nd_lowest.xyz sOT 0.78 0.48s
# The number of candidate molecular level permutations is 58
# Wat_8_cluster_607_1st_lowest.xyz Wat_8_cluster_608_2nd_lowest.xyz sOT 0.61 0.48s
# The number of candidate molecular level permutations is 62
# Wat_9_cluster_1184_1st_lowest.xyz Wat_9_cluster_1185_2nd_lowest.xyz sOT 0.58 0.49s
# The number of candidate molecular level permutations is 292
# Wat_10_cluster_5310_1st_lowest.xyz Wat_10_cluster_5311_2nd_lowest.xyz sOT 0.63 0.82s
# The number of candidate molecular level permutations is 157
# Wat_11_cluster_33413_1st_lowest.xyz Wat_11_cluster_33414_2nd_lowest.xyz sOT 0.91 0.62s
# The number of candidate molecular level permutations is 290
# Wat_12_cluster_43582_1st_lowest.xyz Wat_12_cluster_43583_2nd_lowest.xyz sOT 0.51 0.79s
# The number of candidate molecular level permutations is 77
# Wat_13_cluster_86223_1st_lowest.xyz Wat_13_cluster_86224_2nd_lowest.xyz sOT 0.49 0.55s
# The number of candidate molecular level permutations is 261
# Wat_14_cluster_144675_1st_lowest.xyz Wat_14_cluster_144676_2nd_lowest.xyz sOT 0.48 0.80s
# The number of candidate molecular level permutations is 354
# Wat_15_cluster_225208_1st_lowest.xyz Wat_15_cluster_225209_2nd_lowest.xyz sOT 0.52 0.94s
# The number of candidate molecular level permutations is 253
# Wat_16_cluster_321028_1st_lowest.xyz Wat_16_cluster_321029_2nd_lowest.xyz sOT 0.44 0.87s
# The number of candidate molecular level permutations is 396
# Wat_17_cluster_417887_1st_lowest.xyz Wat_17_cluster_417888_2nd_lowest.xyz sOT 1.20 1.05s
# The number of candidate molecular level permutations is 445
# Wat_18_cluster_524874_1st_lowest.xyz Wat_18_cluster_524875_2nd_lowest.xyz sOT 1.45 1.19s
# The number of candidate molecular level permutations is 390
# Wat_19_cluster_637553_1st_lowest.xyz Wat_19_cluster_637554_2nd_lowest.xyz sOT 0.60 1.12s
# The number of candidate molecular level permutations is 477
# Wat_20_cluster_744361_1st_lowest.xyz Wat_20_cluster_744362_2nd_lowest.xyz sOT 1.69 1.31s
# The number of candidate molecular level permutations is 410
# Wat_21_cluster_865737_1st_lowest.xyz Wat_21_cluster_865738_2nd_lowest.xyz sOT 0.72 1.22s
# The number of candidate molecular level permutations is 334
# Wat_22_cluster_1179799_1st_lowest.xyz Wat_22_cluster_1179800_2nd_lowest.xyz sOT 0.63 1.19s
# The number of candidate molecular level permutations is 213
# Wat_23_cluster_1574510_1st_lowest.xyz Wat_23_cluster_1574511_2nd_lowest.xyz sOT 0.45 1.04s
# The number of candidate molecular level permutations is 398
# Wat_24_cluster_1928474_1st_lowest.xyz Wat_24_cluster_1928475_2nd_lowest.xyz sOT 0.67 1.40s
# The number of candidate molecular level permutations is 209
# Wat_25_cluster_2243803_1st_lowest.xyz Wat_25_cluster_2243804_2nd_lowest.xyz sOT 0.56 1.12s
# The number of candidate molecular level permutations is 463
# Wat_26_cluster_2726710_1st_lowest.xyz Wat_26_cluster_2726711_2nd_lowest.xyz sOT 1.42 1.67s
# The number of candidate molecular level permutations is 477
# Wat_27_cluster_3257213_1st_lowest.xyz Wat_27_cluster_3257214_2nd_lowest.xyz sOT 1.42 1.76s
# The number of candidate molecular level permutations is 466
# Wat_28_cluster_3649358_1st_lowest.xyz Wat_28_cluster_3649359_2nd_lowest.xyz sOT 1.53 1.82s
# The number of candidate molecular level permutations is 487
# Wat_29_cluster_3925395_1st_lowest.xyz Wat_29_cluster_3925396_2nd_lowest.xyz sOT 1.67 2.00s
# The number of candidate molecular level permutations is 455
# Wat_30_cluster_4221226_1st_lowest.xyz Wat_30_cluster_4221227_2nd_lowest.xyz sOT 1.51 1.94s

# %%
combined_df = pd.concat([group1_res, group1_info], axis=1).rename(columns={'Best_RMSD': 'RMSD(ArbAlign)'})
columns_to_plot = ["RMSD(ArbAlign)", "RMSD(OTMol)"]
plt.figure(figsize=(10, 6))
for column in columns_to_plot:
    plt.plot(range(len(combined_df['Wat_num'])), combined_df[column], marker='o', label=column)

plt.xticks(range(len(combined_df['Wat_num'])), combined_df['Wat_num'])
plt.title("RMSD Comparison, WC Benchmark 1st and 2nd")
plt.ylabel("RMSD Values")
plt.ylim(0, 3)
plt.legend()
plt.grid(True)

# %% [markdown]
# group2

# %%
group2_data_path = "../Data/Our_Benchmark_20250410_ver1/Water_Cluster_3_30/water_xyz_output_1st_to_20th"
group2_info = pd.read_csv('../Data/Our_Benchmark_20250410_ver1/Water_Cluster_3_30/water_cluster_largest_RMSD_pair_among_20_lowest_energy.csv')
group2_res = wc_experiment(zip(group2_info['Reference'], group2_info['Target']), group2_data_path, method = method, dataset_name = 'Largest_RMSD')
# Out:
# The number of candidate molecular level permutations is 6
# Wat_3_cluster_0_lowest_1.xyz Wat_3_cluster_1_lowest_2.xyz sOT 1.49 0.43s
# The number of candidate molecular level permutations is 16
# Wat_4_cluster_2_lowest_1.xyz Wat_4_cluster_10_lowest_9.xyz sOT 1.39 0.43s
# The number of candidate molecular level permutations is 53
# Wat_5_cluster_13_lowest_2.xyz Wat_5_cluster_22_lowest_11.xyz sOT 0.88 0.47s
# The number of candidate molecular level permutations is 31
# Wat_6_cluster_42_lowest_12.xyz Wat_6_cluster_50_lowest_20.xyz sOT 1.04 0.45s
# The number of candidate molecular level permutations is 42
# Wat_7_cluster_137_lowest_1.xyz Wat_7_cluster_147_lowest_11.xyz sOT 0.82 0.47s
# The number of candidate molecular level permutations is 31
# Wat_8_cluster_615_lowest_9.xyz Wat_8_cluster_616_lowest_10.xyz sOT 0.72 0.47s
# The number of candidate molecular level permutations is 84
# Wat_9_cluster_1184_lowest_1.xyz Wat_9_cluster_1195_lowest_12.xyz sOT 0.77 0.52s
# The number of candidate molecular level permutations is 12
# Wat_10_cluster_5323_lowest_14.xyz Wat_10_cluster_5324_lowest_15.xyz sOT 0.60 0.45s
# The number of candidate molecular level permutations is 73
# Wat_11_cluster_33413_lowest_1.xyz Wat_11_cluster_33415_lowest_3.xyz sOT 0.62 0.52s
# The number of candidate molecular level permutations is 332
# Wat_12_cluster_43582_lowest_1.xyz Wat_12_cluster_43599_lowest_18.xyz sOT 0.81 0.83s
# The number of candidate molecular level permutations is 117
# Wat_13_cluster_86223_lowest_1.xyz Wat_13_cluster_86236_lowest_14.xyz sOT 0.69 0.60s
# The number of candidate molecular level permutations is 312
# Wat_14_cluster_144683_lowest_9.xyz Wat_14_cluster_144693_lowest_19.xyz sOT 0.76 0.87s
# The number of candidate molecular level permutations is 258
# Wat_15_cluster_225216_lowest_9.xyz Wat_15_cluster_225222_lowest_15.xyz sOT 1.14 0.82s
# The number of candidate molecular level permutations is 398
# Wat_16_cluster_321029_lowest_2.xyz Wat_16_cluster_321036_lowest_9.xyz sOT 1.46 1.05s
# The number of candidate molecular level permutations is 357
# Wat_17_cluster_417889_lowest_3.xyz Wat_17_cluster_417896_lowest_10.xyz sOT 0.52 0.99s
# The number of candidate molecular level permutations is 445
# Wat_18_cluster_524876_lowest_3.xyz Wat_18_cluster_524883_lowest_10.xyz sOT 1.81 1.19s
# The number of candidate molecular level permutations is 382
# Wat_19_cluster_637554_lowest_2.xyz Wat_19_cluster_637555_lowest_3.xyz sOT 0.56 1.10s
# The number of candidate molecular level permutations is 465
# Wat_20_cluster_744373_lowest_13.xyz Wat_20_cluster_744380_lowest_20.xyz sOT 1.15 1.33s
# The number of candidate molecular level permutations is 417
# Wat_21_cluster_865752_lowest_14.xyz Wat_21_cluster_865754_lowest_16.xyz sOT 0.78 1.22s
# The number of candidate molecular level permutations is 424
# Wat_22_cluster_1179802_lowest_4.xyz Wat_22_cluster_1179808_lowest_10.xyz sOT 1.50 1.31s
# The number of candidate molecular level permutations is 216
# Wat_23_cluster_1574526_lowest_17.xyz Wat_23_cluster_1574529_lowest_20.xyz sOT 0.70 1.02s
# The number of candidate molecular level permutations is 274
# Wat_24_cluster_1928487_lowest_14.xyz Wat_24_cluster_1928493_lowest_19.xyz sOT 0.87 1.18s
# The number of candidate molecular level permutations is 245
# Wat_25_cluster_2243818_lowest_16.xyz Wat_25_cluster_2243821_lowest_19.xyz sOT 1.01 1.16s
# The number of candidate molecular level permutations is 467
# Wat_26_cluster_2726711_lowest_2.xyz Wat_26_cluster_2726725_lowest_16.xyz sOT 1.62 1.66s
# The number of candidate molecular level permutations is 473
# Wat_27_cluster_3257215_lowest_3.xyz Wat_27_cluster_3257225_lowest_13.xyz sOT 1.64 1.76s
# The number of candidate molecular level permutations is 457
# Wat_28_cluster_3649363_lowest_6.xyz Wat_28_cluster_3649374_lowest_17.xyz sOT 1.52 1.77s
# The number of candidate molecular level permutations is 475
# Wat_29_cluster_3925402_lowest_8.xyz Wat_29_cluster_3925412_lowest_18.xyz sOT 1.69 1.89s
# The number of candidate molecular level permutations is 444
# Wat_30_cluster_4221227_lowest_2.xyz Wat_30_cluster_4221240_lowest_15.xyz sOT 1.45 1.88s

# %%
combined_df = pd.concat([group2_res, group2_info], axis=1).rename(columns={'Best_RMSD': 'RMSD(ArbAlign)'})
columns_to_plot = ["RMSD(ArbAlign)", "RMSD(OTMol)"]
plt.figure(figsize=(10, 6))
for column in columns_to_plot:
    plt.plot(range(len(combined_df['Wat_num'])), combined_df[column], marker='o', label=column)
plt.xticks(range(len(combined_df['Wat_num'])), combined_df['Wat_num'])
plt.title("RMSD Comparison, Largest ArbAlign RMSD Pair Among 20 Lowest Energy")
plt.ylabel("RMSD Values")
plt.ylim(0, 3.5)
plt.legend()
plt.grid(True)

# %%
combined_df = pd.concat([group1_info, group1_res.rename(columns={'RMSD(OTMol)': 'First vs Second Lowest Energy'}), group2_res.rename(columns={'RMSD(OTMol)': 'Largest ArbAlign RMSD Pair Among 20 Lowest Energy'})], axis=1)
columns_to_plot = ["First vs Second Lowest Energy", "Largest ArbAlign RMSD Pair Among 20 Lowest Energy"]
plt.figure(figsize=(14, 6))
for column in columns_to_plot:
    plt.plot(range(len(combined_df['Wat_num'])), combined_df[column], marker='o', label=column)
plt.xticks(range(len(combined_df['Wat_num'])), combined_df['Wat_num'])
plt.title("RMSD Comparison, WC Benchmark 1st to 20th")
plt.ylabel("RMSD Values")
plt.ylim(0, 2)
plt.legend()
plt.grid(True)
